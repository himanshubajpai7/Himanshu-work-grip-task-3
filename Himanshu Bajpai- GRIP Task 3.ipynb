# %% [markdown]
# # HIMANSHU BAJPAI
# GRIP MARCH 2021,
# TASK 3- Exploratory Data Analysis- Retail

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Himanshu\Downloads\SampleSuperstore.csv")

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
# Checking the missing values
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#Checking for duplicacy
duplicate=df.duplicated()
duplicate.sum()
# Out:
# 17

# %%
dupli = df[df.duplicated()] 
  
print("Duplicate Rows :") 
dupli
# Out:
# Duplicate Rows :
#            Ship Mode      Segment        Country           City         State  \
# 950   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 3406  Standard Class  Home Office  United States       Columbus          Ohio
# 3670  Standard Class     Consumer  United States          Salem        Oregon
# 4117  Standard Class     Consumer  United States    Los Angeles    California
# 4553  Standard Class     Consumer  United States  San Francisco    California
# 5905        Same Day  Home Office  United States  San Francisco    California
# 6146  Standard Class    Corporate  United States  San Francisco    California
# 6334  Standard Class     Consumer  United States  New York City      New York
# 6357  Standard Class    Corporate  United States        Seattle    Washington
# 7608  Standard Class     Consumer  United States  San Francisco    California
# 7735  Standard Class    Corporate  United States        Seattle    Washington
# ...

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
#For full summary of the data frame:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#statistical analysis of the data set
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#To know the names of all the columns:
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#to know the unique observations
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
#Since the dataset has only one country that is United States of America.
df=df.drop('Country',axis=1)
df.head()
# Out:
#         Ship Mode    Segment             City       State  Postal Code Region  \
# 0    Second Class   Consumer        Henderson    Kentucky        42420  South
# 1    Second Class   Consumer        Henderson    Kentucky        42420  South
# 2    Second Class  Corporate      Los Angeles  California        90036   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# # Cleaned Dataset

# %%
df.head(5)
# Out:
#         Ship Mode    Segment             City       State  Postal Code Region  \
# 0    Second Class   Consumer        Henderson    Kentucky        42420  South
# 1    Second Class   Consumer        Henderson    Kentucky        42420  South
# 2    Second Class  Corporate      Los Angeles  California        90036   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# # Insights and Data Visualization

# %%
#Grouping quantity,sales,discount and profit with other columns0
grouped=pd.DataFrame(df.groupby(['Ship Mode','Segment','Category','Sub-Category','State','Region'])['Quantity','Discount','Sales','Profit'].sum().reset_index())
grouped
# Out:
# <ipython-input-42-df697130b7ba>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped=pd.DataFrame(df.groupby(['Ship Mode','Segment','Category','Sub-Category','State','Region'])['Quantity','Discount','Sales','Profit'].sum().reset_index())
#            Ship Mode      Segment    Category Sub-Category       State  \
# 0        First Class     Consumer   Furniture    Bookcases     Arizona
# 1        First Class     Consumer   Furniture    Bookcases  California
# 2        First Class     Consumer   Furniture    Bookcases    Colorado
# 3        First Class     Consumer   Furniture    Bookcases     Florida
# 4        First Class     Consumer   Furniture    Bookcases     Georgia
# ...              ...          ...         ...          ...         ...
# 2978  Standard Class  Home Office  Technology       Phones       Texas
# 2979  Standard Class  Home Office  Technology       Phones     Vermont
# ...

# %%
#sum,mean,min,max,count median,standard deviation,Variance of each states of Profit
df.groupby("State").Profit.agg(["sum","mean","min","max","count","median","std","var"])
# Out:
#                              sum        mean        min        max  count  \
# State
# Alabama                5786.8253   94.865989     0.0000  1459.2000     61
# Arizona               -3427.9246  -15.303235  -814.4832   211.4955    224
# Arkansas               4008.6871   66.811452     1.4190   843.1706     60
# California            76381.3871   38.171608  -325.5720  1906.4850   2001
# Colorado              -6527.8579  -35.867351 -3399.9800   247.9960    182
# Connecticut            3511.4918   42.823071   -15.5826   294.6710     82
# Delaware               9977.3748  103.930988   -48.7839  5039.9856     96
# District of Columbia   1059.5893  105.958930     4.4344   648.5624     10
# Florida               -3399.3017   -8.875461 -1811.0784   327.5922    383
# Georgia               16250.0433   88.315453     0.1134  3177.4750    184
# Idaho                   826.7231   39.367767     1.1151   259.5297     21
# Illinois             -12607.8870  -25.625787 -2929.4845   874.9875    492
# ...

# %%
#To find correlation of the dataset
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
#Ship mode
bins=7
plt.hist(df['Ship Mode'],bins,facecolor='pink',alpha=1)
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category', data=df)
plt.show()

# %%
#Heatmap of the dataset
fig,axes = plt.subplots(1,1,figsize=(9,6))
sns.heatmap(df.corr(), annot= True)
plt.show()

# %%
sns.countplot(x=df['Segment'])

# %%
sns.countplot(x=df['Region'])

# %%
figsize=(15,10)
sns.pairplot(df,hue='Sub-Category')

# %% [markdown]
# ### Sales Insights

# %%
SegSales = df.groupby('Segment').sum().reset_index()
SegSales.Sales.sum()/10**3
SegSales.head()
# Out:
#        Segment  Postal Code         Sales  Quantity  Discount       Profit
# 0     Consumer    288878609  1.161401e+06     19521    820.91  134119.2092
# 1    Corporate    164536330  7.061464e+05     11608    477.85   91979.1340
# 2  Home Office     98157713  4.296531e+05      6744    262.33   60298.6785

# %%
# Segment wise Sales
sns.barplot(x="Sales", y="Segment", data=df, estimator=sum)

# %% [markdown]
# ### Total sales in each sub category

# %%
item_by_subcategory= df.groupby('Sub-Category')
item_by_subcategory.first()
item_by_subcategory.Sales.sum()/10**3
# Out:
# Sub-Category
# Accessories    167.380318
# Appliances     107.532161
# Art             27.118792
# Binders        203.412733
# Bookcases      114.879996
# Chairs         328.449103
# Copiers        149.528030
# Envelopes       16.476402
# Fasteners        3.024280
# Furnishings     91.705164
# Labels          12.486312
# Machines       189.238631
# Paper           78.479206
# Phones         330.007054
# Storage        223.843608
# Supplies        46.673538
# Tables         206.965532
# Name: Sales, dtype: float64

# %%
# Sub-Category wise Sales
plt.figure(figsize=(20, 15))
splot=sns.barplot(x="Sub-Category",y="Sales",data=df, estimator=sum)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=15,
                   xytext = (0,61), 
                   textcoords = 'offset points')
plt.xlabel("Sub-Category", size=14)
plt.ylabel("Sales", size=14)
# Out:
# Text(0, 0.5, 'Sales')

# %%
#Region wise Sales Figures
plt.figure(figsize=(8, 6))
splot=sns.barplot(x="Region",y="Sales",data=df, estimator=sum)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=15,
                   xytext = (0, -31), 
                   textcoords = 'offset points')
plt.xlabel("Region", size=14)
plt.ylabel("Sales", size=14)
# Out:
# Text(0, 0.5, 'Sales')

# %%
# Preferred Delivery Mode 
plt.figure(figsize=(8, 6))
splot=sns.barplot(x="Ship Mode",y="Sales",data=df, estimator=sum)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=15,
                   xytext = (0, -24), 
                   textcoords = 'offset points')
plt.xlabel("Ship Mode", size=14)
plt.ylabel("Sales", size=14)
# Out:
# Text(0, 0.5, 'Sales')

# %%
#Category wise sales in Each region
plt.figure(figsize=[16,10])
splot = sns.barplot(x="Region", y="Sales", hue="Category", data=df, palette="winter")
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=15,
                   xytext = (0, 50), 
                   textcoords = 'offset points')
plt.xlabel("Region")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ### Profit Insights

# %%
sns.set(rc={'figure.figsize':(8,6)})
plots=sns.barplot(x='Region', y='Profit', data=df, estimator=sum)
for bar in plots.patches: 
    
     plots.annotate(format(bar.get_height(), '.2f'),  
                   (bar.get_x() + bar.get_width() / 2,  
                    bar.get_height()), ha='center', va='center', 
                   size=15, xytext=(0, -70), 
                   textcoords='offset points')

# %%
# Category wise Profit
plt.figure(figsize=(9,6))
splot=sns.barplot(x="Category",y="Profit",data=df, estimator=sum)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=15,
                   xytext = (0,70), 
                   textcoords = 'offset points')
plt.xlabel("Category", size=14)
plt.ylabel("Profit", size=14)
# Out:
# Text(0, 0.5, 'Profit')

# %%
# Sub-Category wise Profit
plt.figure(figsize=(20, 15))
splot=sns.barplot(x="Sub-Category",y="Profit",data=df, estimator=sum)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=15,
                   xytext = (0,61), 
                   textcoords = 'offset points')
plt.xlabel("Sub-Category", size=14)
plt.ylabel("Profit", size=14)
# Out:
# Text(0, 0.5, 'Profit')

# %%
# Segment wise Profit
plt.figure(figsize=(8, 5))
splot=sns.barplot(x="Segment",y="Profit",data=df, estimator=sum)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=15,
                   xytext = (0,-65), 
                   textcoords = 'offset points')
plt.xlabel("Segment", size=14)
plt.ylabel("Profit", size=14)
# Out:
# Text(0, 0.5, 'Profit')

# %%
# Category wise Profit
plt.figure(figsize=(9,6))
splot=sns.barplot(x="Category",y="Discount",data=df, estimator=sum)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=15,
                   xytext = (0,-30), 
                   textcoords = 'offset points')
plt.xlabel("Category", size=14)
plt.ylabel("Discount", size=14)
# Out:
# Text(0, 0.5, 'Discount')

# %% [markdown]
# ### Statistical Insights

# %%
# Insights based on Cities
#Sales

grouped= df.groupby("City")
#Aggregated Sales per city
agg_sales=grouped['Sales'].agg(np.sum).sort_values(ascending=False).reset_index()
#Cities with highest total sales
agg_sales.head(10)
# Out:
#             City        Sales
# 0  New York City  256368.1610
# 1    Los Angeles  175851.3410
# 2        Seattle  119540.7420
# 3  San Francisco  112669.0920
# 4   Philadelphia  109077.0130
# 5        Houston   64504.7604
# 6        Chicago   48539.5410
# 7      San Diego   47521.0290
# 8   Jacksonville   44713.1830
# 9    Springfield   43054.3420

# %%
#Let's get some insights based on Cities

grouped= df.groupby("City")
#Aggregated Sales per city
agg_sales=grouped['Sales'].agg(np.sum).sort_values(ascending=True).reset_index()
#Cities with lowest total sales
agg_sales.head()
# Out:
#            City  Sales
# 0       Abilene  1.392
# 1        Elyria  1.824
# 2       Jupiter  2.064
# 3     Pensacola  2.214
# 4  Ormond Beach  2.808

# %% [markdown]
# Marketing techniques could be used and logistics and supply chain should be improved after further analysis of why these Cities have less sales.

# %% [markdown]
# ### Profits

# %%
#Aggregated Profit per city
agg_profit=grouped['Profit'].agg(np.sum).sort_values(ascending=False).reset_index()
#Cities with Highest total Profit
agg_profit.head(10)
# Out:
#             City      Profit
# 0  New York City  62036.9837
# 1    Los Angeles  30440.7579
# 2        Seattle  29156.0967
# 3  San Francisco  17507.3854
# 4        Detroit  13181.7908
# 5      Lafayette  10018.3876
# 6        Jackson   7581.6828
# 7        Atlanta   6993.6629
# 8    Minneapolis   6824.5846
# 9      San Diego   6377.1960

# %% [markdown]
# Though Philadelphia, Houston, Chicago have high sales, there profit are not in top 10. There could be a possibility of inefficient operations management and supply chain or high cost is incured.

# %%
grouped= df.groupby("City")
#Aggregated Profit per city
agg_sales=grouped['Profit'].agg(np.sum).sort_values(ascending=True).reset_index()
#Cities with lowest total profit
agg_sales.head()
# Out:
#            City      Profit
# 0  Philadelphia -13837.7674
# 1       Houston -10153.5485
# 2   San Antonio  -7299.0502
# 3     Lancaster  -7239.0684
# 4       Chicago  -6654.5688

# %% [markdown]
# Though the sales are significantly high in Philadelphia and Houston (in top 10), they operations in these cities are incurring losses. Operations and supply chain management should be improved and more efficiency should be attained. Inventory management is also equally important.

# %% [markdown]
# ### Discount

# %%
#Average Discount per city
avg_dist=grouped['Discount'].agg(np.mean).sort_values(ascending=False).reset_index()
#Cities with highest Average discount
avg_dist.head(10)
# Out:
#             City  Discount
# 0      Deer Park  0.800000
# 1        Abilene  0.800000
# 2  Missouri City  0.800000
# 3     Romeoville  0.800000
# 4      Littleton  0.700000
# 5      Pensacola  0.700000
# 6         Elyria  0.700000
# 7   Ormond Beach  0.700000
# 8          Tyler  0.640000
# 9          Bryan  0.616667

# %% [markdown]
# The cities which topped the Sales and Profit chart are not leading here

# %% [markdown]
# # THANK YOU
